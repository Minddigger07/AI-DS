# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
import pandas as pd


df = pd.read_csv('area.csv')
plt.scatter(df['area'],df['price'])

x = df.iloc[0:14,0:1].values
y = df.iloc[0:14,1:2].values

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x,y)
y_pred= model.predict(x)

plt.scatter(x,y)
plt.title('LINEAR REGRESSION')
plt.xlabel('areas')
plt.ylabel('prices')
plt.plot(x,y_pred,c='orangered')
plt.show()

predit = int(input(" enter the area which price is to be predicted: "))
print(model.predict([[predit]]))
# Out:
#  enter the area which price is to be predicted: 1360
# [[740295.68272164]]

# %%
# Out:
# LinearRegression()

# %%
# Out:
# array([[ 570235.37025053],
#        [ 806430.24868263],
#        [ 948147.17574189],
#        [1231581.0298604 ],
#        [1515014.88397892],
#        [1751209.76241102],
#        [ 759191.27299621],
#        [ 711952.29730979],
#        [ 664713.32162337],
#        [ 617474.34593695],
#        [1160722.56633078],
#        [1326058.98123324],
#        [1420536.93260608],
#        [1656731.81103818]])

# %%
m = model.coef_
m
# Out:
# array([[472.38975686]])

# %%
c = model.intercept_
c
# Out:
# array([97845.61338634])

# %%
model.predict([[1240]])
# Out:
# array([[683608.91189794]])
